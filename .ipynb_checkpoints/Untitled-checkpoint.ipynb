# %%
import csv
with open('staticfiles/station_TPTC.csv','r', encoding='utf-8-sig') as csvFile:
    rows = csv.reader(csvFile, delimiter=',')
    for row in rows:
        print(row)
        row.append(row)
print(len(row))
i=0
for item in row:
    print(item)
    i = i+1
    print(i)
# Out:
# ['松山機場', '中山國中', '南京復興', '忠孝復興', '大安', '科技大樓', '六張犁', '麟光', '辛亥', '萬芳醫院', '萬芳社區', '木柵', '動物園', '大直', '劍南路', '西湖', '港墘', '文德', '內湖', '大湖公園', '葫洲', '東湖', '南港軟體園區', '南港展覽館', '小碧潭', '新店', '新店區公所', '七張', '大坪林', '景美', '萬隆', '公館', '台電大樓', '古亭', '中正紀念堂', '小南門', '頂溪', '永安市場', '景安', '南勢角', '台大醫院', '台北車站', '中山', '雙連', '民權西路', '圓山', '劍潭', '士林', '芝山', '明德', '石牌', '唭哩岸', '奇岩', '北投', '新北投', '復興崗', '忠義', '關渡', '竹圍', '紅樹林', '淡水', '頂埔', '永寧', '土城', '海山', '亞東醫院', '府中', 'BL板橋', '新埔', '江子翠', '龍山寺', '西門', '善導寺', '忠孝新生', '忠孝敦化', '國父紀念館', '市政府', '永春', '後山埤', '昆陽', '南港', '象山', '台北101/世貿', '信義安和', '大安森林公園', '北門', '松江南京', '台北小巨蛋', '南京三民', '松山', '輔大', '新莊', '頭前庄', '先嗇宮', '三重', '菜寮', '台北橋', '大橋頭', '中山國小', '行天宮', '東門', '蘆洲', '三民高中', '徐匯中學', '三和國中', '三重國小', '迴龍', '丹鳳', '十四張', '秀朗橋', '景平', '中和', '橋和', '中原', '板新', 'Y板橋', '新埔民生', '幸福', '新北產業園區']
# 120
# 1
# 松山機場
# 2
# 中山國中
# 3
# 南京復興
# 4
# 忠孝復興
# 5
# 大安
# 6
# 科技大樓
# 7
# 六張犁
# 8
# 麟光
# 9
# 辛亥
# 10
# 萬芳醫院
# 11
# 萬芳社區
# 12
# 木柵
# 13
# 動物園
# 14
# 大直
# 15
# 劍南路
# 16
# 西湖
# 17
# 港墘
# 18
# 文德
# 19
# 內湖
# 20
# 大湖公園
# 21
# 葫洲
# 22
# 東湖
# 23
# 南港軟體園區
# 24
# 南港展覽館
# 25
# 小碧潭
# 26
# 新店
# 27
# 新店區公所
# 28
# 七張
# 29
# 大坪林
# 30
# 景美
# 31
# 萬隆
# 32
# 公館
# 33
# 台電大樓
# 34
# 古亭
# 35
# 中正紀念堂
# 36
# 小南門
# 37
# 頂溪
# 38
# 永安市場
# 39
# 景安
# 40
# 南勢角
# 41
# 台大醫院
# 42
# 台北車站
# 43
# 中山
# 44
# 雙連
# 45
# 民權西路
# 46
# 圓山
# 47
# 劍潭
# 48
# 士林
# 49
# 芝山
# 50
# 明德
# 51
# 石牌
# 52
# 唭哩岸
# 53
# 奇岩
# 54
# 北投
# 55
# 新北投
# 56
# 復興崗
# 57
# 忠義
# 58
# 關渡
# 59
# 竹圍
# 60
# 紅樹林
# 61
# 淡水
# 62
# 頂埔
# 63
# 永寧
# 64
# 土城
# 65
# 海山
# 66
# 亞東醫院
# 67
# 府中
# 68
# BL板橋
# 69
# 新埔
# 70
# 江子翠
# 71
# 龍山寺
# 72
# 西門
# 73
# 善導寺
# 74
# 忠孝新生
# 75
# 忠孝敦化
# 76
# 國父紀念館
# 77
# 市政府
# 78
# 永春
# 79
# 後山埤
# 80
# 昆陽
# 81
# 南港
# 82
# 象山
# 83
# 台北101/世貿
# 84
# 信義安和
# 85
# 大安森林公園
# 86
# 北門
# 87
# 松江南京
# 88
# 台北小巨蛋
# 89
# 南京三民
# 90
# 松山
# 91
# 輔大
# 92
# 新莊
# 93
# 頭前庄
# 94
# 先嗇宮
# 95
# 三重
# 96
# 菜寮
# 97
# 台北橋
# 98
# 大橋頭
# 99
# 中山國小
# 100
# 行天宮
# 101
# 東門
# 102
# 蘆洲
# 103
# 三民高中
# 104
# 徐匯中學
# 105
# 三和國中
# 106
# 三重國小
# 107
# 迴龍
# 108
# 丹鳳
# 109
# 十四張
# 110
# 秀朗橋
# 111
# 景平
# 112
# 中和
# 113
# 橋和
# 114
# 中原
# 115
# 板新
# 116
# Y板橋
# 117
# 新埔民生
# 118
# 幸福
# 119
# 新北產業園區
# 120
# ['松山機場', '中山國中', '南京復興', '忠孝復興', '大安', '科技大樓', '六張犁', '麟光', '辛亥', '萬芳醫院', '萬芳社區', '木柵', '動物園', '大直', '劍南路', '西湖', '港墘', '文德', '內湖', '大湖公園', '葫洲', '東湖', '南港軟體園區', '南港展覽館', '小碧潭', '新店', '新店區公所', '七張', '大坪林', '景美', '萬隆', '公館', '台電大樓', '古亭', '中正紀念堂', '小南門', '頂溪', '永安市場', '景安', '南勢角', '台大醫院', '台北車站', '中山', '雙連', '民權西路', '圓山', '劍潭', '士林', '芝山', '明德', '石牌', '唭哩岸', '奇岩', '北投', '新北投', '復興崗', '忠義', '關渡', '竹圍', '紅樹林', '淡水', '頂埔', '永寧', '土城', '海山', '亞東醫院', '府中', 'BL板橋', '新埔', '江子翠', '龍山寺', '西門', '善導寺', '忠孝新生', '忠孝敦化', '國父紀念館', '市政府', '永春', '後山埤', '昆陽', '南港', '象山', '台北101/世貿', '信義安和', '大安森林公園', '北門', '松江南京', '台北小巨蛋', '南京三民', '松山', '輔大', '新莊', '頭前庄', '先嗇宮', '三重', '菜寮', '台北橋', '大橋頭', '中山國小', '行天宮', '東門', '蘆洲', '三民高中', '徐匯中學', '三和國中', '三重國小', '迴龍', '丹鳳', '十四張', '秀朗橋', '景平', '中和', '橋和', '中原', '板新', 'Y板橋', '新埔民生', '幸福', '新北產業園區', [...]]
